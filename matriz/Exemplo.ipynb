# %% [markdown]
# Exemplo prático

# %%
num1 = int(input("Informe um número para a posição [0][0] da matriz: "))
num2 = int(input("Informe um número para a posição [1][0] da matriz: "))
num3 = int(input("Informe um número para a posição [0][1] da matriz: "))
num4 = int(input("Informe um número para a posição [0][1] da matriz: "))

matriz = [
[num1,num2],
[num3,num4]
]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 num1 = int(input("Informe um número para a posição [0][0] da matriz"))
#       2 num2 = int(input("Informe um número para a posição [1][0] da matriz"))
#       3 num3 = int(input("Informe um número para a posição [0][1] da matriz"))
#       4 num4 = int(input("Informe um número para a posição [0][1] da matriz"))
#
# ValueError: invalid literal for int() with base 10: ''
